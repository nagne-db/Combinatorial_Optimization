# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
composite_df = pd.read_csv('/Users/rangpe/Desktop/projects/Combinatorial_Optimization/src/datasets/NASA_Exoplanet_Composite.csv')
planet_df = pd.read_csv('/Users/rangpe/Desktop/projects/Combinatorial_Optimization/src/datasets/NASA_Exoplanet_Planetary.csv')
# Out:
# /var/folders/m_/qzrd1wjj49j__zg7g2kkfknw0000gn/T/ipykernel_1303/75469218.py:2: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   planet_df = pd.read_csv('/Users/rangpe/Desktop/projects/Combinatorial_Optimization/src/datasets/NASA_Exoplanet_Planetary.csv')

# %%
composite_df.iloc[:,:12]
# Out:
#       rowid     pl_name  hostname pl_letter    hd_name    hip_name  \
# 0         1    11 Com b    11 Com         b  HD 107383   HIP 60202
# 1         2    11 UMi b    11 UMi         b  HD 136726   HIP 74793
# 2         3    14 And b    14 And         b  HD 221345  HIP 116076
# 3         4    14 Her b    14 Her         b  HD 145675   HIP 79248
# 4         5  16 Cyg B b  16 Cyg B         b  HD 186427   HIP 96901
# ...     ...         ...       ...       ...        ...         ...
# 5478   5479   ups And b   ups And         b    HD 9826    HIP 7513
# 5479   5480   ups And c   ups And         c    HD 9826    HIP 7513
# 5480   5481   ups And d   ups And         d    HD 9826    HIP 7513
# 5481   5482   ups Leo b   ups Leo         b        NaN         NaN
# 5482   5483    xi Aql b    xi Aql         b  HD 188310   HIP 97938
#
#              tic_id                       gaia_id  sy_snum  sy_pnum  sy_mnum  \
# 0      TIC 72437047  Gaia DR2 3946945413106333696        2        1        0
# ...

# %%
composite_df['pl_name'].nunique()
# Out:
# 5483

# %%
plt.hist(composite_df.hostname.value_counts(), bins = 8)
plt.show()
